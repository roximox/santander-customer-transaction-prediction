# %% [markdown]
# # 08 — Final Evaluation
#
# **Objective:** Plan a single unbiased final evaluation and reporting workflow.
# **Owner:** TBD
# **Sprint:** TBD
#
# > Leakage warning: access the test set only after model and threshold selection are frozen.

# %%
from pathlib import Path

project_root = next(path for path in (Path.cwd(), *Path.cwd().parents) if (path / "configs" / "config.yaml").is_file())
import sys
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
from src.config import load_config

config = load_config()
print(config["project"]["name"])
print(config["project"]["random_state"])

# %% [markdown]
# ## Planned work
#
# Later: freeze the selected pipeline, evaluate once on held-out data, report all agreed metrics, limitations, and reproducibility references.
